# %%
import numpy as np
import pandas as pd
np.random.seed(1)

# %%
full_labels = pd.read_csv('data/all_labels.csv')

# %%
full_labels.head()
len(full_labels) #There are ___ objects
# Out:
# 1238

# %%
grouped = full_labels.groupby('filename')
print(grouped)

# %%
grouped.apply(lambda x: len(x)).value_counts()
# Out:
# 1      172
# 2      100
# 3       50
# 4       25
# 6       10
# 5        9
# 7        3
# 482      1
# 8        1
# dtype: int64

# %% [markdown]
# ### split each file into a group in a list

# %%
gb = full_labels.groupby('filename')
print(gb)

# %%
grouped_list2 = [gb.get_group(x) for x in gb.groups]
print(grouped_list2)
# Out:
# [            filename  width  height class  xmin  ymin  xmax  ymax
# 0  brushSY_00006.JPG   4000    3000   dog  3274  1261  3650  1448,             filename  width  height         class  xmin  ymin  xmax  ymax
# 1  brushSY_00007.JPG   4000    3000           dog  2797  1139  2906  1306
# 2  brushSY_00007.JPG   4000    3000  nonMotorized  3257   755  3603  1481,             filename  width  height class  xmin  ymin  xmax  ymax
# 3  brushSY_00008.JPG   4000    3000   dog  3479  1268  3793  1508,             filename  width  height class  xmin  ymin  xmax  ymax
# 4  brushSY_00010.JPG   4000    3000   dog  3406  1521  3959  2109,             filename  width  height class  xmin  ymin  xmax  ymax
# 5  brushSY_00011.JPG   4000    3000   dog  2897  1139  3020  1373,             filename  width  height class  xmin  ymin  xmax  ymax
# 6  brushSY_00012.JPG   4000    3000   dog  3028  1075  3123  1203,             filename  width  height         class  xmin  ymin  xmax  ymax
# ...

# %%
len(grouped_list2) #There are 518 images
# Out:
# 371

# %%
train_index = np.random.choice(len(grouped_list), size=350, replace=False)
test_index = np.setdiff1d(list(range(371)), train_index)

# %%
len(train_index), len(test_index)
# Out:
# (350, 21)

# %%
# take first 200 files

for i in train_index:
    print(grouped_list[i])
train = pd.concat([grouped_list[i] for i in train_index])
test = pd.concat([grouped_list[i] for i in test_index])
# Out:
#                filename  width  height         class  xmin  ymin  xmax  ymax
# 604  gothicSY_00088.JPG   4000    3000  nonMotorized     1   657   141  1743
# 605  gothicSY_00088.JPG   4000    3000  nonMotorized   221   743   715  1764
#               filename  width  height         class  xmin  ymin  xmax  ymax
# 124  brushSY_00097.JPG   4000    3000  nonMotorized  3159   839  3244  1108
#               filename  width  height class  xmin  ymin  xmax  ymax
# 119  brushSY_00091.JPG   4000    3000   dog  3429  1557  3959  2034
#                filename  width  height         class  xmin  ymin  xmax  ymax
# 310  cementSY_00009.JPG   4000    3000     motorized  1485  1487  1815  1692
# 311  cementSY_00009.JPG   4000    3000  nonMotorized  1872  1406  1948  1624
# 312  cementSY_00009.JPG   4000    3000     motorized  2091  1457  2375  1752
#                filename  width  height         class  xmin  ymin  xmax  ymax
# ...

# %%
len(train), len(test)
# Out:
# (1196, 42)

# %%
train.to_csv('data/train_labels.csv', index=None)
test.to_csv('data/test_labels.csv', index=None)
