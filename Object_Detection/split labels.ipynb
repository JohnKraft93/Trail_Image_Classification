# %%
import numpy as np
import pandas as pd
np.random.seed(1)

# %%
full_labels = pd.read_csv('data/all_labels.csv')

# %%
full_labels.head()
len(full_labels) #There are 657 objects
# Out:
# 657

# %%
grouped = full_labels.groupby('filename')
print(grouped)

# %%
grouped.apply(lambda x: len(x)).value_counts()
# Out:
# 1    439
# 2     45
# 3     18
# 4      9
# 5      5
# 7      1
# 6      1
# dtype: int64

# %% [markdown]
# ### split each file into a group in a list

# %%
gb = full_labels.groupby('filename')

# %%
grouped_list = [gb.get_group(x) for x in gb.groups]

# %%
len(grouped_list) #There are 518 images
# Out:
# 518

# %%
train_index = np.random.choice(len(grouped_list), size=500, replace=False)
test_index = np.setdiff1d(list(range(518)), train_index)

# %%
len(train_index), len(test_index)
# Out:
# (500, 18)

# %%
# take first 200 files

for i in train_index:
    print(grouped_list[i])
train = pd.concat([grouped_list[i] for i in train_index])
test = pd.concat([grouped_list[i] for i in test_index])
# Out:
#                                         filename  width  height   class  xmin  \
# 277  motorized_1_noDogs_2018-12-14--08-02-09.JPG   4000    3000  person   804
#
#      ymin  xmax  ymax
# 277  1391  1146  2037
#                                         filename  width  height    class  \
# 126  motorized_1_noDogs_2018-12-09--04-10-53.JPG   4000    3000  groomer
#
#      xmin  ymin  xmax  ymax
# 126     1   595   678  2518
#                                         filename  width  height   class  xmin  \
# 330  motorized_1_noDogs_2018-12-15--11-04-45.JPG   4000    3000  person   754
#
#      ymin  xmax  ymax
# 330  1400  1066  1987
#                                         filename  width  height   class  xmin  \
# 388  motorized_1_noDogs_2018-12-30--11-39-03.JPG   4000    3000  person   358
#
#      ymin  xmax  ymax
# 388  1362   858  1986
#                                         filename  width  height   class  xmin  \
# ...

# %%
len(train), len(test)
# Out:
# (633, 24)

# %%
train.to_csv('data.train_labels.csv', index=None)
test.to_csv('test_labels.csv', index=None)
